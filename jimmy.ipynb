# %%
# !python -m pip install -e .
# Out:
# Obtaining file:///mnt/c/Users/jimmy/Documents/ECE%20C147/147final
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for emg2qwerty (pyproject.toml) ... done
#   Created wheel for emg2qwerty: filename=emg2qwerty-0.1.0-0.editable-py3-none-any.whl size=9401 sha256=bee04332231f3079d6df6b91e0a97f669d07f7f6b1d7532619415d40947dc04d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q8k2o3nh/wheels/ad/83/d5/5874f8d347740fe9885f27078fab5854781574136e490c44ac
# Successfully built emg2qwerty
# ...

# %%
# tdsConvLstmCtc - with log mel_spectrogram transform

# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 29659
# [2025-03-14 00:13:11,046][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# tdsConvLstmCtc - with log=false mel_spectrogram transform

# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 11535
# [2025-03-14 00:40:02,700][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# tdsConvLstmCtc - with log=false mel_spectrogram transform min 10 max 500

# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 18240
# [2025-03-14 00:52:28,962][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# tdsConvLstmCtc - with pywt wavelet transform (NOTE EXTREMELY SLOW DONT USE)   min_freq: 10 max_freq: 500 None log: false

# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 4124
# [2025-03-14 01:25:28,473][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# transformer_ctc
# module:
#   _target_: emg2qwerty.lightning.TransformerCTCModule
#   in_features: 528  # freq * channels = (n_fft // 2 + 1) * 16
#   mlp_features: [384]
#   d_model: 128
#   nhead: 4
#   num_encoder_layers: 4
#   dim_feedforward: 256
#   dropout: 0.1
#   use_cross_wrist_attention: false # Enable/disable attention between left and right wrists
#   use_cross_sensor_attention: false # Enable/disable attention between the 16 EMG channels on each hand
#   loss_type: 'ctc' # or 'cross_entropy'

# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 3482
# [2025-03-14 02:23:04,794][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# transformer_ctc
# module:
#   _target_: emg2qwerty.lightning.TransformerCTCModule
#   in_features: 528  # freq * channels = (n_fft // 2 + 1) * 16
#   mlp_features: [384]
#   d_model: 128
#   nhead: 6
#   num_encoder_layers: 4
#   dim_feedforward: 256
#   dropout: 0.1
#   use_cross_wrist_attention: true # Enable/disable attention between left and right wrists
#   use_cross_sensor_attention: true # Enable/disable attention between the 16 EMG channels on each hand
#   loss_type: 'ctc' # or 'cross_entropy'

# defaults:
#   - user: single_user
#   - transforms: mel_spectrogram
#   - model: transformer_ctc #tdsConvLstmCtc #tds_conv_ctc #tdsConvLstmCtc
#   - optimizer: adamW
#   - lr_scheduler: linear_warmup_cosine_annealing  # oneCycleLR
#   - decoder: ctc_greedy
#   - cluster: local
#   - _self_

# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 17183
# [2025-03-14 02:48:14,129][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# transformer_ctc
# module:
#   _target_: emg2qwerty.lightning.TransformerCTCModule
#   in_features: 528  # freq * channels = (n_fft // 2 + 1) * 16
#   mlp_features: [384]
#   d_model: 384
#   nhead: 6
#   num_encoder_layers: 4
#   dim_feedforward: 768
#   dropout: 0.0
#   use_cross_wrist_attention: false # Enable/disable attention between left and right wrists
#   use_cross_sensor_attention: false # Enable/disable attention between the 16 EMG channels on each hand
#   loss_type: 'ctc' # or 'cross_entropy'

# defaults:
#   - user: single_user
#   - transforms: mel_spectrogram
#   - model: transformer_ctc #tdsConvLstmCtc #tds_conv_ctc #tdsConvLstmCtc
#   - optimizer: adamW
#   - lr_scheduler: linear_warmup_cosine_annealing  # oneCycleLR
#   - decoder: ctc_greedy
#   - cluster: local
#   - _self_

# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 24996
# [2025-03-14 03:02:26,571][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# transformer_ctc
# module:
#   _target_: emg2qwerty.lightning.TransformerCTCModule
#   in_features: 528  # freq * channels = (n_fft // 2 + 1) * 16
#   mlp_features: [384]
#   d_model: 384
#   nhead: 6
#   num_encoder_layers: 4
#   dim_feedforward: 1536
#   dropout: 0.0
#   use_cross_wrist_attention: false # Enable/disable attention between left and right wrists
#   use_cross_sensor_attention: false # Enable/disable attention between the 16 EMG channels on each hand
#   loss_type: 'ctc' # or 'cross_entropy'

# defaults:
#   - user: single_user
#   - transforms: mel_spectrogram
#   - model: transformer_ctc #tdsConvLstmCtc #tds_conv_ctc #tdsConvLstmCtc
#   - optimizer: adamW
#   - lr_scheduler: linear_warmup_cosine_annealing  # oneCycleLR
#   - decoder: ctc_greedy
#   - cluster: local
#   - _self_

# batch_size: 16 # instead of 32

# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 28097
# [2025-03-14 03:07:48,661][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# TINY TRANSFORMER
# module:
#   _target_: emg2qwerty.lightning.TransformerCTCModule
#   in_features: 528  # freq * channels = (n_fft // 2 + 1) * 16
#   mlp_features: [384]
#   d_model: 128
#   nhead: 4
#   num_encoder_layers: 2
#   dim_feedforward: 512
#   dropout: 0.0
#   use_cross_wrist_attention: false # Enable/disable attention between left and right wrists
#   use_cross_sensor_attention: false # Enable/disable attention between the 16 EMG channels on each hand
#   loss_type: 'ctc' # or 'cross_entropy'

# defaults:
#   - user: single_user
#   - transforms: mel_spectrogram
#   - model: transformer_ctc #tdsConvLstmCtc #tds_conv_ctc #tdsConvLstmCtc
#   - optimizer: adamW
#   - lr_scheduler: oneCycleLR  # oneCycleLR
#   - decoder: ctc_greedy
#   - cluster: local
#   - _self_

# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 2980
# [2025-03-14 03:20:35,940][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="logs/2025-03-14/03-20-35/checkpoints/epoch-29-step-3600.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64
# Out:
# 15685
# [2025-03-14 22:29:51,820][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# TDSConvTransformerCTCModule mel min 10 max 500
# module:
#   _target_: emg2qwerty.lightning.TDSConvTransformerCTCModule
#   in_features: 528  # freq * channels = (n_fft // 2 + 1) * 16
#   mlp_features: [384]
#   block_channels: [24, 24, 24, 24]
#   kernel_width: 32  # Total temporal receptive field of 125 samples given 4 layers
#   d_model: 256
#   nhead: 8
#   num_encoder_layers: 6
#   dim_feedforward: 1024
#   dropout: 0.0

# defaults:
#   - user: single_user
#   - transforms: mel_spectrogram
#   - model: conv_transformer_ctc #tdsConvLstmCtc #tds_conv_ctc #tdsConvLstmCtc
#   - optimizer: adamW
#   - lr_scheduler: oneCycleLR  # oneCycleLR
#   - decoder: ctc_greedy
#   - cluster: local
#   - _self_


# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 25822
# [2025-03-14 04:02:00,956][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user testing
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint='logs/2025-03-14/04-02-00/checkpoints/epoch-27-step-3360.ckpt' \
  train=False  trainer.accelerator=gpu \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=64 
  # --multirun
# Out:
# 26887
# [2025-03-14 05:02:13,282][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# TDSConvTransformerCTCModule mel min 10 max 500
# module:
#   _target_: emg2qwerty.lightning.TDSConvTransformerCTCModule
#   in_features: 528  # freq * channels = (n_fft // 2 + 1) * 16
#   mlp_features: [384]
#   block_channels: [24, 24, 24, 24]
#   kernel_width: 32  # Total temporal receptive field of 125 samples given 4 layers
#   d_model: 384
#   nhead: 8
#   num_encoder_layers: 4
#   dim_feedforward: 1536
#   dropout: 0.1

# defaults:
#   - user: single_user
#   - transforms: mel_spectrogram
#   - model: conv_transformer_ctc #tdsConvLstmCtc #tds_conv_ctc #tdsConvLstmCtc
#   - optimizer: adamW
#   - lr_scheduler: oneCycleLR  # oneCycleLR
#   - decoder: ctc_greedy
#   - cluster: local
#   - _self_


# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 6599
# [2025-03-14 05:23:01,877][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# TDSConvLstmCTCModule
# module:
#   _target_: emg2qwerty.lightning.TDSConvLstmCTCModule
#   in_features: 528  # freq * channels = (n_fft // 2 + 1) * 16
#   mlp_features: [384]
#   block_channels: [24, 24, 24, 24]
#   kernel_width: 32  # Total temporal receptive field of 125 samples given 4 layers
#   lstm_hidden_size: 256
#   num_lstm_layers: 4

# defaults:
#   - user: single_user
#   - transforms: mel_spectrogram
#   - model: tdsConvLstmCtc #tdsConvLstmCtc #tds_conv_ctc #tdsConvLstmCtc
#   - optimizer: adamW
#   - lr_scheduler: oneCycleLR  # oneCycleLR
#   - decoder: ctc_greedy
#   - cluster: local
#   - _self_


# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 25000
# [2025-03-14 05:56:52,677][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# TDSConvTransformerCTCModule mel min 0 max None
# module:
#   _target_: emg2qwerty.lightning.TDSConvTransformerCTCModule
#   in_features: 528  # freq * channels = (n_fft // 2 + 1) * 16
#   mlp_features: [384]
#   block_channels: [24, 24, 24, 24]
#   kernel_width: 32  # Total temporal receptive field of 125 samples given 4 layers
#   d_model: 384
#   nhead: 8
#   num_encoder_layers: 4
#   dim_feedforward: 1536
#   dropout: 0.1

# defaults:
#   - user: single_user
#   - transforms: mel_spectrogram
#   - model: conv_transformer_ctc #tdsConvLstmCtc #tds_conv_ctc #tdsConvLstmCtc
#   - optimizer: adamW
#   - lr_scheduler: oneCycleLR  # oneCycleLR
#   - decoder: ctc_greedy
#   - cluster: local
#   - _self_

# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 11680
# [2025-03-14 06:32:26,028][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
#OG
# defaults:
#   - user: single_user
#   - transforms: log_spectrogram
#   - model: og #tdsConvLstmCtc #tds_conv_ctc #tdsConvLstmCtc
#   - optimizer: adam
#   - lr_scheduler: linear_warmup_cosine_annealing  # oneCycleLR
#   - decoder: ctc_greedy
#   - cluster: local
#   - _self_

# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1

# %%
# TDSConvLstmCTCModule
# module:
#   _target_: emg2qwerty.lightning.TDSConvLstmCTCModule
#   in_features: 528  # freq * channels = (n_fft // 2 + 1) * 16
#   mlp_features: [384]
#   block_channels: [24, 24, 24, 24]
#   kernel_width: 32  # Total temporal receptive field of 125 samples given 4 layers
#   lstm_hidden_size: 256
#   num_lstm_layers: 4

# defaults:
#   - user: single_user
#   - transforms: mel_spectrogram
#   - model: tdsConvLstmCtc #tdsConvLstmCtc #tds_conv_ctc #tdsConvLstmCtc
#   - optimizer: adamW
#   - lr_scheduler: oneCycleLR  # oneCycleLR
#   - decoder: ctc_greedy
#   - cluster: local
#   - _self_


# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 3191
# [2025-03-14 12:05:00,628][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# TDSConvLstmCTCModule
# module:
#   _target_: emg2qwerty.lightning.TDSConvLstmCTCModule
#   in_features: 528  # freq * channels = (n_fft // 2 + 1) * 16
#   mlp_features: [384]
#   block_channels: [24, 24, 24, 24]
#   kernel_width: 32  # Total temporal receptive field of 125 samples given 4 layers
#   lstm_hidden_size: 256
#   num_lstm_layers: 4

# defaults:
#   - user: single_user
#   - transforms: mel_spectrogram
#   - model: tdsConvLstmCtc #tdsConvLstmCtc #tds_conv_ctc #tdsConvLstmCtc
#   - optimizer: adamW
#   - lr_scheduler: linear_warmup_cosine_annealing  # oneCycleLR
#   - decoder: ctc_greedy
#   - cluster: local
#   - _self_


# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/mnt/c/Users/jimmy/Documents/ECE C147/147final/emg2qwerty/train.py", line 14, in <module>
#     import torch
#   File "/mnt/c/Users/jimmy/Documents/ECE C147/emg2qwerty/.venv/lib/python3.11/site-packages/torch/__init__.py", line 1598, in <module>
#     import torch.utils.data
#   File "/mnt/c/Users/jimmy/Documents/ECE C147/emg2qwerty/.venv/lib/python3.11/site-packages/torch/utils/data/__init__.py", line 21, in <module>
#     from torch.utils.data.datapipes.datapipe import (
#   File "/mnt/c/Users/jimmy/Documents/ECE C147/emg2qwerty/.venv/lib/python3.11/site-packages/torch/utils/data/datapipes/__init__.py", line 1, in <module>
#     from . import iter
#   File "/mnt/c/Users/jimmy/Documents/ECE C147/emg2qwerty/.venv/lib/python3.11/site-packages/torch/utils/data/datapipes/iter/__init__.py", line 33, in <module>
# ...

# %%
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="logs/2025-03-14/13-38-11/checkpoints/epoch-128-step-15480.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  decoder=ctc_beam \
  hydra.launcher.mem_gb=64
# Out:
# 26511
# [2025-03-14 23:49:41,218][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# TDSConvLstmCTCModule
# module:
#   _target_: emg2qwerty.lightning.TDSConvLstmCTCModule
#   in_features: 528  # freq * channels = (n_fft // 2 + 1) * 16
#   mlp_features: [384]
#   block_channels: [24, 24, 24, 24]
#   kernel_width: 32  # Total temporal receptive field of 125 samples given 4 layers
#   lstm_hidden_size: 256
#   num_lstm_layers: 4

# defaults:
#   - user: single_user
#   - transforms: mel_spectrogram
#   - model: tdsConvLstmCtc #tdsConvLstmCtc #tds_conv_ctc #tdsConvLstmCtc
#   - optimizer: adamW
#   - lr_scheduler: linear_warmup_cosine_annealing  # oneCycleLR
#   - decoder: ctc_greedy
#   - cluster: local
#   - _self_


# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 9709
# [2025-03-14 16:11:54,819][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# TDSConvTransformerCTCModule
# module:
#   _target_: emg2qwerty.lightning.TDSConvTransformerCTCModule
#   in_features: 528  # freq * channels = (n_fft // 2 + 1) * 16
#   mlp_features: [384]
#   block_channels: [24, 24, 24, 24]
#   kernel_width: 32  # Total temporal receptive field of 125 samples given 4 layers
#   d_model: 384
#   nhead: 8
#   num_encoder_layers: 4
#   dim_feedforward: 1536
#   dropout: 0.1

# defaults:
#   - user: single_user
#   - transforms: mel_spectrogram
#   - model: conv_transformer_ctc #tdsConvLstmCtc #tds_conv_ctc #tdsConvLstmCtc
#   - optimizer: adamW
#   - lr_scheduler: linear_warmup_cosine_annealing  # oneCycleLR
#   - decoder: ctc_greedy
#   - cluster: local
#   - _self_


# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 21066
# [2025-03-14 18:14:37,441][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %% [markdown]
# ### last one had loss explosion

# %%
# TDSConvTransformerCTCModule
# module:
#   _target_: emg2qwerty.lightning.TDSConvTransformerCTCModule
#   in_features: 528  # freq * channels = (n_fft // 2 + 1) * 16
#   mlp_features: [384]
#   block_channels: [24, 24, 24, 24]
#   kernel_width: 32  # Total temporal receptive field of 125 samples given 4 layers
#   d_model: 384
#   nhead: 8
#   num_encoder_layers: 4
#   dim_feedforward: 1536
#   dropout: 0.1
#   use_layer_norm: True
#   transformer_norm_first: True

# defaults:
#   - user: single_user
#   - transforms: mel_spectrogram
#   - model: conv_transformer_ctc #tdsConvLstmCtc #tds_conv_ctc #tdsConvLstmCtc
#   - optimizer: adamW
#   - lr_scheduler: linear_warmup_cosine_annealing  # oneCycleLR
#   - decoder: ctc_greedy
#   - cluster: local
#   - _self_


# !HYDRA_FULL_ERROR=1 python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1
# Out:
# 19449
# [2025-03-14 19:38:03,559][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# !python -m emg2qwerty.train \
  user="single_user" \
  checkpoint="logs/2025-03-14/19-38-03/checkpoints/epoch-133-step-16080.ckpt" \
  train=False \
  trainer.accelerator=gpu \
  decoder=ctc_beam \
  hydra.launcher.mem_gb=64
# Out:
# 7595
# [2025-03-14 22:15:06,598][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %% [markdown]
# ### BASE MODEL 150 EPOCH trained in other notebook
# ```
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00,  8.38it/s]
# ────────────────────────────────────────────────────────────────────────────────
# Runningstage.validating metric      DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#          val/CER            19.206911087036133
#          val/DER             1.151971697807312
#          val/IER            6.1586174964904785
#          val/SER            11.896322250366211
#         val/loss             1.016243577003479
# ────────────────────────────────────────────────────────────────────────────────
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|███████████████████████| 1/1 [00:04<00:00,  4.43s/it]
# ────────────────────────────────────────────────────────────────────────────────
# Runningstage.testing metric      DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test/CER            21.871623992919922
#         test/DER            1.7938188314437866
#         test/IER             5.424681186676025
#         test/SER            14.653122901916504
#         test/loss           1.1261004209518433
# ────────────────────────────────────────────────────────────────────────────────
# {'val_metrics': [{'val/loss': 1.016243577003479,
#                   'val/CER': 19.206911087036133,
#                   'val/IER': 6.1586174964904785,
#                   'val/DER': 1.151971697807312,
#                   'val/SER': 11.896322250366211}],
#  'test_metrics': [{'test/loss': 1.1261004209518433,
#                    'test/CER': 21.871623992919922,
#                    'test/IER': 5.424681186676025,
#                    'test/DER': 1.7938188314437866,
#                    'test/SER': 14.653122901916504}],
#  'best_checkpoint': '/mnt/c/Users/jimmy/Documents/ECE '
#                     'C147/emg2qwerty/logs/2025-03-14/16-20-24/checkpoints/epoch=133-step=16080.ckpt'}
# ```

# %%
#
